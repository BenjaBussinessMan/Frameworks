# %%
#pip install semantic-kernel
#pip install nest_asyncio
# Out:
#   Cell In[9], line 2
#     pip install nest_asyncio
#         ^
# SyntaxError: invalid syntax

# %%
import asyncio
import nest_asyncio  # <--- 1. Importar
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.functions import KernelArguments

# %%
nest_asyncio.apply()

# %%
async def main():
    # 1. Inicializar el Kernel
    kernel = Kernel()

    # 2. Configurar el servicio de IA (OpenAI en este caso)
    service_id = "asistente_chat"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
            api_key="TU_API_KEY_AQUI",
            ai_model_id="gpt-4o"
        )
    )

    # 3. Definir una "Plugin" semántica (Prompt Engineering)
    # En Semantic Kernel, los prompts se tratan como funciones.
    prompt_template = """
    Eres un experto en atención al cliente. Analiza el siguiente comentario:
    
    Comentario: {{$input}}
    
    Por favor, responde con el siguiente formato:
    - Sentimiento: (Positivo/Negativo/Neutral)
    - Resumen: (Máximo 10 palabras)
    - Acción recomendada: (Breve sugerencia)
    """

    # Registrar la función en el kernel
    analisis_feedback = kernel.add_function(
        function_name="AnalizarFeedback",
        plugin_name="MarketingPlugin",
        prompt=prompt_template
    )

    # 4. Caso práctico: Ejecución con un comentario real
    comentario_cliente = """
    El producto llegó dos días tarde y la caja estaba un poco abollada, 
    pero debo decir que el equipo funciona de maravilla y el soporte técnico 
    fue muy amable al ayudarme con la configuración inicial.
    """

    # Ejecutar la función
    resultado = await kernel.invoke(
        analisis_feedback, 
        KernelArguments(input=comentario_cliente)
    )

    print("--- ANÁLISIS DEL ASISTENTE ---")
    print(resultado)

# %%
if __name__ == "__main__":
    asyncio.run(main()) # <--- Ahora esto ya no dará error
# Out:
# Function failed. Error: Error occurred while invoking function AnalizarFeedback: ("<class 'semantic_kernel.connectors.ai.open_ai.services.open_ai_chat_completion.OpenAIChatCompletion'> service failed to complete the prompt", APIConnectionError('Connection error.'))
# Something went wrong in function invocation. During function invocation: 'MarketingPlugin-AnalizarFeedback'. Error description: 'Error occurred while invoking function AnalizarFeedback: ("<class 'semantic_kernel.connectors.ai.open_ai.services.open_ai_chat_completion.OpenAIChatCompletion'> service failed to complete the prompt", APIConnectionError('Connection error.'))'
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\sbonilla\.conda\envs\SEC\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# ...
